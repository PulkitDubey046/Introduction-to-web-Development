# %% [markdown]
# # **Q1. Create a simple page with some div tags and show different ways to add CSS as well as what happens when you target the same elements with inline, internal, and external CSS. Also, utilize comments in the project where required.**

# %% [markdown]
# **The three types of CSS:**
# 1.   Inline CSS
# 2.   Internal CSS
# 3.   External CSS
#
#
#
# **What happens when we target the same elements with Inline, Internal and External CSS?**
# 1.   Inline CSS overrides both internal and external CSS.
# 2.   Internal CSS overrides external CSS but is overridden by inline.
# 3.   External CSS has the lowest priority.
# 4.   All styles still merge, unless they override the same property.
#
#
# **code11.html**
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Adding CSS to our web-page</title>
#     <!-- 2. Internal CSS -->
#     <style>
#       #inter {
#         color: orange;
#         text-transform: uppercase;
#         text-decoration: underline red wavy 1px;
#         line-height: 50px;
#       }
#
#       #all{
#         color: red;
#       }
#     </style>
#     <!-- 3. External CSS -->
#     <link rel="stylesheet" href="code11.css" />
#   </head>
#   <body>
#     <!-- 1. Inline CSS -->
#     <div style="color: brown; font-size: xx-large">Pulkit Dubey</div>
#
#     <!-- 2. Internal CSS using id-->
#     <div id="inter">Pulkit Dubey</div>
#
#     <!-- 3. External CSS -->
#     <div id="exter">Pulkit Dubey</div>
#
#     <!-- targeting the same elements with inline, internal, and external CSS -->
#     <div
#       id="all"
#       style="font-size: 40px; color: black; text-shadow: 2px 2px 2px orange; line-height: 150px;"
#     >
#       Bholenath Computer Academy
#     </div>
#   </body>
# </html>
#
# ```
#
# **code11.css**
#
#
# ```
# #exter{
#     color: yellow;
#     font-size: 40px;
#     font-weight: bold;
#     text-shadow: 2px 2px 2px black;
# }
# #all{
#     color: blue;
# }
# ```

# %% [markdown]
# # **Q2. Build an HTML page with multiple paragraphs, each assigned a unique class name. Write CSS rules using class selectors to apply distinct styling to each paragraph. Follow the BEM naming convention and explain how you've named the classes.**

# %% [markdown]
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <title>Bholenath Computer Academy</title>
#   <style>
#     /* General Styling */
#     body {
#       font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#       background-color: #f4f6f8;
#       margin: 0;
#       padding: 20px;
#     }
#
#     h1 {
#       text-align: center;
#       color: #2980b9;
#       margin-bottom: 30px;
#     }
#
#     /* BEM Classes for Paragraph Styling */
#     .academy__paragraph--intro {
#       background-color: #e3f2fd;
#       border-left: 5px solid #2196f3;
#       padding: 15px;
#       margin-bottom: 15px;
#       font-size: 18px;
#       color: #0d47a1;
#     }
#
#     .academy__paragraph--courses {
#       background-color: #fff3e0;
#       border-left: 5px solid #ff9800;
#       padding: 15px;
#       margin-bottom: 15px;
#       font-weight: bold;
#       color: #e65100;
#     }
#
#     .academy__paragraph--quote {
#       font-style: italic;
#       color: #555;
#       background-color: #f1f8e9;
#       border-left: 5px solid #8bc34a;
#       padding: 15px;
#       margin-bottom: 15px;
#     }
#
#     .academy__paragraph--achievements {
#       background-color: #fce4ec;
#       border-left: 5px solid #e91e63;
#       padding: 15px;
#       margin-bottom: 15px;
#       color: #880e4f;
#     }
#
#     .academy__paragraph--contact {
#       background-color: #e0f7fa;
#       border-top: 2px dashed #00acc1;
#       padding: 15px;
#       color: #006064;
#     }
#   </style>
# </head>
# <body>
#
#   <h1>Bholenath Computer Academy</h1>
#
#   <div class="academy">
#     <p class="academy__paragraph--intro">
#       Welcome to Bholenath Computer Academy! We are dedicated to providing top-quality computer education for students of all levels.
#     </p>
#
#     <p class="academy__paragraph--courses">
#       🔥 Our Popular Courses: ADCA, DCA, Tally with GST, Web Development, Python Programming, and more.
#     </p>
#
#     <p class="academy__paragraph--quote">
#       "Empowering students through digital education is our mission. Learn today, lead tomorrow."
#     </p>
#
#     <p class="academy__paragraph--achievements">
#       🏆 We’ve trained over 1000+ students successfully with high placement rates and industry-ready skills.
#     </p>
#
#     <p class="academy__paragraph--contact">
#       💻 Subscribe:
#       <a href="https://www.youtube.com/channel/UCtr7pzByR_TQjyzMpSeILzQ" target="_blank">YouTube Channel</a>
#     </p>
#   </div>
#
# </body>
# </html>
#
# ```

# %% [markdown]
# #**Q3. Develop an HTML form with various input elements. Use CSS to style the form, including setting background colors for input fields. Create a custom color palette for the form elements, and demonstrate how to apply opacity to one of the form sections.**

# %% [markdown]
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <title>Registration Form – Bholenath Computer Academy</title>
#   <style>
#     :root {
#       --primary-color: #1abc9c;
#       --secondary-color: #1fa016;
#       --accent-color: #82745e;
#       --background-light: #f8febb;
#       --text-dark: #0d0d0e;
#     }
#
#     body {
#       font-family: Arial, sans-serif;
#       background-color: var(--background-light);
#       margin: 0;
#       padding: 40px;
#     }
#
#     h2 {
#       text-align: center;
#       color: var(--text-dark);
#     }
#
#     form {
#       max-width: 600px;
#       margin: 0 auto;
#       background-color: white;
#       padding: 25px;
#       border-radius: 10px;
#       box-shadow: 0 4px 10px rgba(0, 0, 0, 0.1);
#     }
#
#     .form-group {
#       margin-bottom: 15px;
#     }
#
#     label {
#       display: block;
#       margin-bottom: 5px;
#       font-weight: bold;
#       color: var(--text-dark);
#     }
#
#     input[type="text"],
#     input[type="email"],
#     input[type="tel"],
#     input[type="date"],
#     select,
#     textarea {
#       width: 100%;
#       padding: 10px;
#       border: 1px solid var(--secondary-color);
#       border-radius: 5px;
#       background-color: var(--background-light);
#       color: var(--text-dark);
#     }
#
#     input[type="submit"] {
#       background-color: var(--primary-color);
#       color: white;
#       padding: 12px 20px;
#       border: none;
#       border-radius: 5px;
#       font-size: 16px;
#       cursor: pointer;
#     }
#
#     input[type="submit"]:hover {
#       background-color: var(--secondary-color);
#     }
#
#     .form-group--faded {
#       opacity: 0.6;
#       background-color: #fff9e6;
#       padding: 10px;
#       border-radius: 5px;
#     }
#   </style>
# </head>
# <body>
#
#   <h2>Student Registration - Bholenath Computer Academy</h2>
#
#   <form>
#     <div class="form-group">
#       <label for="name">Full Name</label>
#       <input type="text" id="name" name="name" placeholder="Enter your full name">
#     </div>
#
#     <div class="form-group">
#       <label for="email">Email Address</label>
#       <input type="email" id="email" name="email" placeholder="Enter your email">
#     </div>
#
#     <div class="form-group">
#       <label for="phone">Phone Number</label>
#       <input type="tel" id="phone" name="phone" placeholder="Enter your contact number">
#     </div>
#
#     <div class="form-group form-group--faded">
#       <label for="dob">Date of Birth</label>
#       <input type="date" id="dob" name="dob">
#     </div>
#
#     <div class="form-group">
#       <label for="course">Select Course</label>
#       <select id="course" name="course">
#         <option value="">-- Select --</option>
#         <option value="adca">ADCA</option>
#         <option value="dca">DCA</option>
#         <option value="webdev">Web Development</option>
#         <option value="python">Python Programming</option>
#       </select>
#     </div>
#
#     <div class="form-group">
#       <label for="message">Why do you want to join?</label>
#       <textarea id="message" name="message" rows="4" placeholder="Tell us something..."></textarea>
#     </div>
#
#     <input type="submit" value="Register Now">
#   </form>
#
# </body>
# </html>
#
# ```
